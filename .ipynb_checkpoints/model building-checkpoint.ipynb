# %%
import joblib
from sklearn import tree

# %%
X = [[45],[55]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)

# %%
clf.predict([[55]])[0]
# Out:
# 1

# %%
tree.plot_tree(clf)
# Out:
# [Text(167.4, 163.07999999999998, 'X[0] <= 50.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
joblib.dump(clf, 'classifier.pkl')
# Out:
# ['classifier.pkl']
